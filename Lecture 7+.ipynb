# %% [markdown]
# #Lecture 7
#
# http://introtodeeplearning.com/slides/6S191_MIT_DeepLearning_L7.pdf
#
# https://www.youtube.com/watch?v=4PuuziOgSU4&list=PLtBw6njQRU-rwp5__7C0oIVt26ZgjG9NI&index=7

# %% [markdown]
# What i got from this lecture is basically that AI has various cavebeats and we are not sure why, for example:
# * AI can be easily "attacked" to detect other things or not detect something at al.
#   * Modifing an image really slightly in the right way gives something different
#   * Modifying the context.
#   * Even in real life by crafting some "props" one can fool an AI.
#
# Something else they mentioned is that there is another type of AI, a symbolic AI, that could help AI to improve

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# They combined this two AI, and built a neuro-symbolic system.
#
# this combines the strenght of both types of AI.
#
# 1. Use the CNN for vision. (Vision CNN)
# 2. De-render the results into a structured representation. (Structured representation)
# 3. (which is simultanious with 1) Uses a Language (RNN).
# 4. Combine 1. and 3. and parse it into a symbolic program.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# None, hybrids are Reinforcement learning types because you need to train both networks

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Another advantage of this hybrid methods is that they need less training data.
# Also it is more transparent and interpretable

# %% [markdown]
# Neuro-Symbolic Concept Learning
# This basically can learn what things are from context. Eg. it can learn that green is a colour, from context.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)![image.png]()

# %% [markdown]
# ![image.png](data:image/png;base64,...)
